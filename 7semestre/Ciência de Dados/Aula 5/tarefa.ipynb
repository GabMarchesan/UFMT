# %% [markdown]
# # Renda Per capita Domiciliar vs Escolaridade

# %%
import basedosdados as bd

billing_id = <seu_billing_id>

query = """
  SELECT
    dados.ano as ano,
    dados.sigla_uf AS sigla_uf,
    diretorio_sigla_uf.nome AS sigla_uf_nome,
    dados.anos_escolares as anos_escolares,
    dados.taxa_aprovacao as taxa_aprovacao,
    dados.indicador_rendimento as indicador_rendimento,
    dados.ideb as ideb
FROM `basedosdados.br_inep_ideb.uf` AS dados
LEFT JOIN (SELECT DISTINCT sigla,nome  FROM `basedosdados.br_bd_diretorios_brasil.uf`) AS diretorio_sigla_uf
    ON dados.sigla_uf = diretorio_sigla_uf.sigla
"""

bd.read_sql(query = query, billing_project_id = billing_id)

billing_id = <seu_billing_id>

query = """
  SELECT
    dados.sigla_uf AS sigla_uf,
    diretorio_sigla_uf.nome AS sigla_uf_nome,
    dados.situacao_domicilio as situacao_domicilio,
    dados.v6531 as v6531
FROM `basedosdados.br_ibge_censo_demografico.microdados_domicilio_2010` AS dados
LEFT JOIN (SELECT DISTINCT sigla,nome  FROM `basedosdados.br_bd_diretorios_brasil.uf`) AS diretorio_sigla_uf
    ON dados.sigla_uf = diretorio_sigla_uf.sigla
"""

bd.read_sql(query = query, billing_project_id = billing_id)
# Out:
#   Cell In[1], line 3
#     billing_id = <seu_billing_id>
#                  ^
# SyntaxError: invalid syntax
